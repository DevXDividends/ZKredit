# %%
import numpy as np 
import pandas as pd 
import matplotlib as mp 
from sklearn.model_selection import train_test_split

# %%
def load_dataset():
    return pd.read_csv("../loan_data.csv")

# %%
loanData = load_dataset()
